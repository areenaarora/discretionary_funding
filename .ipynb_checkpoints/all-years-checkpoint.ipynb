# %%
import pandas as pd
df = pd.read_csv('all-years.csv')
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.lower()
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df.head(3)
# Out:
#      mocs_id  fiscal_year                            source council_member  \
# 0  FY09 5052         2009  Transportation - Operating Costs            NaN
# 1  FY09 5053         2009  Transportation - Operating Costs            NaN
# 2  FY09 6008         2009     HIV/AIDS Communities of Color            NaN
#
#                    legal_name_of_organization            ein   status  \
# 0  Community Agency for Senior Citizens, Inc. 133,263,537.00  Cleared
# 1  Community Agency for Senior Citizens, Inc. 133,263,537.00  Cleared
# 2          AIDS Center of Queens County, Inc. 112,837,894.00  Cleared
#
#      amount agency                        program_name address  \
# 0  7,481.30   DFTA  Case Assistance and Transportation     NaN
# 1  7,481.30   DFTA  Case Assistance and Transportation     NaN
# 2 42,068.00  DOHMH                                 NaN     NaN
#
#   address_2_(optional) city state postcode purpose_of_funds  \
# 0                  NaN  NaN   NaN      NaN              NaN
# ...

# %%
df.query('status == "Cleared"').groupby(by='fiscal_year').amount.sum()
# Out:
# fiscal_year
# 2009   413,533,653.62
# 2010   356,091,046.56
# 2011   386,278,150.55
# 2012   386,157,779.00
# 2013   287,519,171.00
# 2014   392,655,570.00
# 2015   285,921,446.00
# 2016   380,361,130.00
# 2017   352,389,921.00
# 2018   380,849,210.00
# 2019   392,443,523.00
# 2020   455,329,202.00
# 2021   371,322,848.00
# Name: amount, dtype: float64

# %%
# pd.set_option('display.max_rows', None)
# df.groupby(['fiscal_year', 'borough']).amount.sum()

# %%
df.query('legal_name_of_organization == "City University of New York"').query('status == "Cleared"').groupby(by='fiscal_year').amount.sum()
# Out:
# fiscal_year
# 2012    3,550,000.00
# 2014    6,093,500.00
# 2015   17,875,000.00
# 2016   21,412,000.00
# 2017   21,392,500.00
# 2018   21,346,469.00
# 2019   23,628,939.00
# 2020   28,824,104.00
# 2021   26,377,964.00
# Name: amount, dtype: float64

# %%
df.query('legal_name_of_organization == "City University of New York"').fiscal_year.unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
df.query('legal_name_of_organization == "City University of New York"').groupby(by='fiscal_year').amount.sum()
# Out:
# fiscal_year
# 2012    3,550,000.00
# 2013    2,746,137.00
# 2014    6,093,500.00
# 2015   17,875,000.00
# 2016   21,412,000.00
# 2017   21,392,500.00
# 2018   21,346,469.00
# 2019   23,628,939.00
# 2020   28,824,104.00
# 2021   26,377,964.00
# Name: amount, dtype: float64

# %%
df.query('legal_name_of_organization == "City University of New York"').query('fiscal_year == 2013')
# Out:
#          mocs_id  fiscal_year                                         source  \
# 23299  FY13 1037         2013                Center for Puerto Rican Studies
# 23301  FY13 1041         2013                        CUNY Nursing Initiative
# 23302  FY13 1044         2013   Murphy Institute Center for Worker Education
# 23303  FY13 1043         2013              Hunter College Food Policy Center
# 23304  FY13 1042         2013                    Dominican Studies Institute
# 23305  FY13 1040         2013                           CUNY Citizenship NOW
# 25235  FY13 1038         2013                             Creative Arts Team
# 25878  FY13 1039         2013              CUNY Advanced Certificate Program
# 26172  FY13 1045         2013  Technical Assistance for Child Care Providers
#
#       council_member   legal_name_of_organization            ein      status  \
# 23299            NaN  City University of New York 136,400,434.00  Government
# ...

# %%
df.query('fiscal_year == 2009').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#      legal_name_of_organization         amount
# 2116  School Budget Restoration 120,000,000.00

# %%
df.query('fiscal_year == 2010').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#                           legal_name_of_organization        amount
# 581  Community College Administration and Operations 21,900,000.00

# %%
df.query('fiscal_year == 2011').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#     legal_name_of_organization        amount
# 753   Fire Company Restoration 37,386,289.00

# %%
df.query('fiscal_year == 2012').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#     legal_name_of_organization        amount
# 826            Fire Department 40,903,754.00

# %%
df.query('fiscal_year == 2013').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#     legal_name_of_organization        amount
# 808   Fire Company Restoration 43,582,294.00

# %%
df.query('fiscal_year == 2014').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#       legal_name_of_organization        amount
# 878  Fire Department of New York 43,682,294.00

# %%
df.query('fiscal_year == 2015').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#                         legal_name_of_organization        amount
# 662  Department of Youth and Community Development 32,935,801.00

# %%
df.query('fiscal_year == 2016').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#                         legal_name_of_organization        amount
# 631  Department of Youth and Community Development 34,535,000.00

# %%
df.query('fiscal_year == 2017').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#       legal_name_of_organization        amount
# 461  City University of New York 21,392,500.00

# %%
df.query('fiscal_year == 2018').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#     legal_name_of_organization        amount
# 608    Department of Education 26,420,467.00

# %%
df.query('fiscal_year == 2019').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#     legal_name_of_organization        amount
# 614    Department of Education 29,300,109.00

# %%
df.query('fiscal_year == 2020').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#       legal_name_of_organization        amount
# 475  City University of New York 28,824,104.00

# %%
df.query('fiscal_year == 2021').query('status == "Cleared"').groupby(by='legal_name_of_organization').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(1)
# Out:
#       legal_name_of_organization        amount
# 442  City University of New York 26,377,964.00

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %%
pd.set_option('display.max_rows', None)
df.groupby(['fiscal_year', 'borough']).amount.sum()
# Out:
# fiscal_year  borough
# 2009         BRONX         9,226,157.59
#              BROOKLYN     25,649,654.23
#              MANHATTAN    73,570,858.99
#              QUEENS       14,945,803.25
#              STATEN IS     3,721,168.34
# 2010         BRONX        12,815,624.90
#              BROOKLYN     27,041,499.40
#              MANHATTAN    90,334,682.32
#              QUEENS       15,382,123.59
#              STATEN IS     4,892,970.40
# 2011         BRONX        11,153,605.26
#              BROOKLYN     23,114,383.24
#              MANHATTAN    73,320,778.75
#              QUEENS       13,363,489.18
#              STATEN IS     5,103,523.84
# 2012         BRONX         6,588,618.00
#              BROOKLYN     16,299,521.00
#              MANHATTAN    33,578,239.00
#              QUEENS        9,243,714.00
#              STATEN IS     4,367,507.00
# 2013         BRONX        20,380,485.00
#              BROOKLYN     44,817,557.00
#              MANHATTAN    71,062,852.00
# ...

# %%
from plotnine import *

# %%
(
    ggplot(df,          # data
        aes('fiscal_year', 'amount', color='borough')) # aesthetics
        + geom_bar(stat='identity')
)
# Out:
# <ggplot: (329437710)>

# %%
df.query('legal_name_of_organization == "City University of New York"')
# Out:
#           mocs_id  fiscal_year  \
# 17390   FY12 4563         2012
# 17391   FY12 4551         2012
# 17392   FY12 4560         2012
# 17393   FY12 4562         2012
# 17394   FY12 4561         2012
# ...           ...          ...
# 89934  FY21 01045         2021
# 89935  FY21 09065         2021
# 89936  FY21 05535         2021
# 89937  FY21 06203         2021
# 89938  FY21 06179         2021
#
#                                                   source council_member  \
# 17390       Murphy Institute Center for Worker Education            NaN
# 17391                                 Creative Arts Team            NaN
# 17392                    Center for Puerto Rican Studies            NaN
# 17393                        Dominican Studies Institute            NaN
# 17394                               CUNY Nursing Program            NaN
# ...                                                  ...            ...
# 89934                                              Local        Vallone
# ...

# %%
df.query('legal_name_of_organization == "City University of New York"').source.value_counts().reset_index()
# Out:
#                                                 index  source
# 0                                               Local     200
# 1                           Adult Literacy Initiative      16
# 2                    Create New Technology Incubators      12
# 3                            CUNY Research Institutes      10
# 4                                  Creative Arts Team       8
# 5              Cultural After-School Adventure (CASA)       6
# 6                                        Anti-Poverty       6
# 7   Worker Cooperative Business Development Initia...       5
# 8   Joseph S. Murphy Institute Center for Worker E...       5
# 9        Murphy Institute Center for Worker Education       5
# 10                    Center for Puerto Rican Studies       5
# 11                        Dominican Studies Institute       5
# 12                     Veterans Community Development       4
# 13                      Cultural Immigrant Initiative       4
# ...

# %%
df.groupby(by='source').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(5)
# Out:
#                                      source         amount
# 419                                   Local 473,122,974.00
# 277                Fire Company Restoration 182,463,631.00
# 568               School Budget Restoration 120,000,000.00
# 188  Cultural After-School Adventure (CASA) 112,211,500.00
# 209                Discretionary Child Care 110,026,491.00

# %%
df.groupby(by='program_name').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(5)
# Out:
#                                program_name        amount
# 9839  Peter F. Vallone Academic Scholarship 48,035,607.00
# 4341               Fire Company Restoration 43,582,294.00
# 6499                       Jobs to Build On 19,526,065.00
# 2257            Center for Court Innovation 11,098,101.00
# 1977                  CUNY Citizenship Now!  8,564,500.00

# %%
df.groupby(by='program_name').amount.sum().reset_index().sort_values(by='amount', ascending = True).head(5)
# Out:
#               program_name  amount
# 6394            Jacob Riis  400.00
# 131   344 East 28th Street  400.00
# 984          Baruch Houses  400.00
# 7154     Lower East Side V  400.00
# 4856        Gompers Houses  400.00

# %%
df.query('program_name == "Peter F. Vallone Academic Scholarship"')
# Out:
#           mocs_id  fiscal_year                                 source  \
# 69804  FY19 05379         2019  Peter F. Vallone Academic Scholarship
# 70382  FY19 05380         2019  Peter F. Vallone Academic Scholarship
# 79719  FY20 06870         2020  Peter F. Vallone Academic Scholarship
# 80413  FY20 06871         2020  Peter F. Vallone Academic Scholarship
# 89936  FY21 05535         2021  Peter F. Vallone Academic Scholarship
# 90495  FY21 05536         2021  Peter F. Vallone Academic Scholarship
#
#       council_member   legal_name_of_organization            ein   status  \
# 69804            NaN  City University of New York 133,893,536.00  Cleared
# 70382            NaN      Department of Education 136,400,434.00  Cleared
# 79719            NaN  City University of New York 133,893,536.00  Cleared
# 80413            NaN      Department of Education 136,400,434.00  Cleared
# 89936            NaN  City University of New York 133,893,536.00  Cleared
# ...

# %%
df.groupby(by='council_member').amount.sum().reset_index().sort_values(by='amount', ascending = False).head(5)
# Out:
#           council_member         amount
# 108              Speaker 227,384,273.00
# 22              Citywide 117,776,078.86
# 92     Queens Delegation  26,093,749.07
# 15   Brooklyn Delegation  26,013,763.94
# 7                 Barron  20,124,238.96
